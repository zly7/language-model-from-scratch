# %%
from datasets import load_dataset, DatasetDict, load_from_disk
import torch


# preprocessed_splits = load_from_disk("../processed_datadir2/wikitext-103-story-bert-2048")
preprocessed_splits = load_from_disk("../processed_datadir2/wikitext-103-story-gpt2-2048/")
print("train length :", len(preprocessed_splits["train"]))
# Out:
# train length : 70057

# %%
for i in range(10):
    print(preprocessed_splits["validation"][i])
# Out:
# {'input_ids': [465, 2095, 705, 82, 29184, 286, 465, 11989, 837, 12316, 837, 366, 632, 28674, 572, 7288, 837, 340, 28674, 572, 514, 355, 10544, 837, 340, 28674, 572, 262, 5386, 4964, 837, 780, 4844, 286, 514, 1107, 2993, 810, 356, 547, 8066, 467, 764, 366, 2102, 837, 339, 37857, 326, 1757, 705, 82, 14052, 329, 465, 4028, 373, 2233, 284, 1719, 3725, 326, 8168, 2073, 550, 764, 220, 198, 5856, 3227, 286, 3115, 11802, 705, 82, 717, 1622, 837, 10805, 373, 635, 1762, 319, 262, 2523, 775, 5379, 290, 13980, 705, 82, 28880, 9145, 837, 523, 339, 373, 1690, 11300, 736, 290, 6071, 1022, 5401, 5652, 290, 10930, 764, 770, 46414, 379, 1661, 351, 10805, 705, 82, 7205, 837, 355, 339, 550, 5876, 1972, 366, 40868, 2488, 12, 31, 331, 1576, 366, 706, 42458, 262, 3621, 2095, 286, 360, 11870, 10343, 421, 5857, 319, 13980, 705, 82, 28880, 9145, 764, 10805, 16476, 837, 366, 314, 373, 7819, 287, 360, 11870, 2488, 12, 31, 1956, 837, 810, 314, 373, 852, 1165, 3621, 764, 40868, 705, 82, 7069, 284, 1064, 764, 360,
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(f"../tokenizer_save/tokenizer-gpt2-2048")

# %%
print(tokenizer.eos_token)
# Out:
# <|endoftext|>

# %%
print(tokenizer.pad_token)
# Out:
# <|endoftext|>

# %%
for i in range(10):
    print(preprocessed_splits["train"][0]['input_ids'])

# %%
preprocessed_splits2 = load_from_disk("../processed_datadir2/wikitext-103-story-chartoken-bert-2048/")
print("train length :", len(preprocessed_splits2["train"]))
# Out:
# train length : 269508

# %%
# print("train[0] :", preprocessed_splits["train"][0])
print("train[0] type :", type(preprocessed_splits["train"][0]['input_ids'][0]))
print("train[0] type :", type(preprocessed_splits2["train"][0]['input_ids'][0]))
# Out:
# train[0] type : <class 'int'>
# train[0] type : <class 'int'>

# %%
how_many = 10
for i in preprocessed_splits["train"]:
    print(i)
    how_many -= 1
    if how_many == 0:
        break
